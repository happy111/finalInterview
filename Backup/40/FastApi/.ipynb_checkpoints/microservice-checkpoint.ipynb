# %%
Service Mesh
************

    Handles service-to-service communication, observability, security

Circuit Breaker
**************
    pip install pybreaker requests
    
Load Balancer	
*************
    Distributes traffic across multiple instances of a service
    
API Gateway
**********
    Acts as the single entry point for all clients, handles routing, auth,
    rate limiting
        (e.g., Kong, NGINX, Netflix Zuul).
