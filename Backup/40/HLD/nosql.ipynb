# %%
Nosql

Casandra & MongoDB

NOSQL  - Non-Relational data

BASE : Availability attain

Amazon DynamoDB <String,String>
Casandra DB [cOLUMN BASED store]
MongoDB (Document based store)

# %%
   Client-> Server->DB

Horizonatal scaling in DB -> shading

   Modulo Approach        was difficult
   Consistent hashing
