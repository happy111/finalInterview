# %%
       Messaging Queue

Producer  ->        Queue  ->                    Consumer

Message Produce                                  message consume

Benefits of producer/consumer

1. Producer and consumer can work on there own pace.

# %%
Kafka :

   1. Patch Matching
   2.

# %%
Architecture :

  Producer
  Consumer
  broker
  Topic
  Partition
  Consumer Group
  Cluser
  Zookeper,kraft
  offset

# %%
                Producer                         Kafka Server(Broker)                                 Consumer

                                                     Topic0   p1,p2
                                                     Topic1   p1,p2

# %%
                Producer                         Kafka Server(Broker)                                 Consumer

# %%
If number of partitions are less than number of consumers, some consumers will remail idle.

    1 Consumer can consume multiple partitions

    1 partitions can be consumed by only 1 consumer

    Autobalancing

# %%
Why kafka does all this?

Consumer Group is fairly new kafks

Messagequeue serve 2 purpose
  1. Queue FIFO
  2. pub/sub

# %%
PUB/ SUB MODEL

  Publisher -> Queue ->  Subscriber
                     -> Subscriber

1 producer -> Many Consumer

# %%
Zookeeper :- Stores all information

EX : Consumer Group : 1
     Consumer : 1
     Topic : 0
     Partition : 0
     Offset : 0

# %%
Cluster : Group of broker [Leader and Follower]

Leader : Read and write
Follower : will just follow(listen)  the leader


Producer :
  Key      Unique ID (Optional)
  Value    Actual Msg
  Topic    topic0
  Partition  0    (Optional)

   Round Robin

# %%
Dead Letter Queue :-

    Mag : Consumer cannot re resolved
Consumer put in special queuqe is called DLQ.

A Dead Letter Queue is a special queue where messages are 
sent when they cannot be processed successfully after multiple retry attempts.

# %%
Rabbit MQ:-
*********

# %%
Kafka : Pull based technique
Rabbit MQ : Push based technique

# %%
Caching :-

server                 cache(Faster accesible unit)                        DB

TTL  (Time to live)

Cache : Temporary storage (TTL) time to live

Cache : Expensive

# %%
Cache Technique :

  1. CDN [static resource]
  2. Load Balancer(Web pages)
  3. Server side caching(Redis)
  4. Proxies also use caching

# %%
Cache Data POST/ GET

1. Cache Aside technique (Retrieve)

    server cache  DB
    
    1. Check cache
    2. If found(cache hit) return the data
    3. If not fetch the data from db
    4. put it into the cache and then return the data
2. Read through cache
