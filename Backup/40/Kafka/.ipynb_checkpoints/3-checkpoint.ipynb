# %%
1. Scenario: Your consumer is missing some messages. 
  What could be the reason?
  . Auto offset reset is set to latest instead of earliest.
  . Offset commit failed or was not configured properly
  . Messages might have expired if retention period is low.
  . Message filtering logic is incorrect and skipping messages.

# %%
Kafka Scenario-Based Interview Questions & Answers
