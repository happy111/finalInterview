# %%
def longestSubstringKDistinct(s, k):
    if k == 0:
        return 0
    left = 0
    freq = {}
    max_len = 0
    for right in range(len(s)):
        freq[s[right]] = freq.get(s[right], 0) + 1
        while len(freq) > k:
            print("Before remove", freq)
            freq[s[left]] -= 1
            if freq[s[left]] == 0:
                del freq[s[left]]
            left += 1

        max_len = max(max_len, right - left + 1)
    return max_len
    
s = "eceba"
k = 2
print(longestSubstringKDistinct(s, k))  # Output: 3
# Out:
# Before remove {'e': 2, 'c': 1, 'b': 1}
# After remove {'e': 1, 'c': 1, 'b': 1}
# Before remove {'e': 1, 'c': 1, 'b': 1}
# After remove {'e': 1, 'c': 0, 'b': 1}
# Before remove {'e': 1, 'b': 1, 'a': 1}
# After remove {'e': 0, 'b': 1, 'a': 1}
# 3

# %%
print("dd`")
# Out:
# dd`
