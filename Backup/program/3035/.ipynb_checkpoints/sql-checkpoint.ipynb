# %%
ACID:
*****

A : Atomicity
*************
    1. A transaction is all or nothing.
    2. Either all operations succeed, or none do.
    3. If any part of the transaction fails, the entire transaction is rolled back.

Example: Transferring money between two accounts—if debit succeeds but credit fails,
the debit must also be undone.

C :  Consistency
****************
    A transaction takes the database from one valid state to another.

I – Isolation
    Concurrent transactions don’t interfere with each other.

    Example: Two users updating the same product stock should not 
    overwrite each other's changes.

D :  Once a transaction is committed, it is permanently saved
