# %%
Secure Api
*********

To secure APIs, I implement authentication, authorization, rate limiting, 
    input validation,
    encryption,
    and secure headers. 
    I also monitor logs .

# %%
 1. Authentication
Ensure only valid users can access your API.
✅ Use:
JWT (JSON Web Tokens) for stateless auth
OAuth2 for delegated access (e.g., Google login)
API Keys for service-to-service auth (less secure than JWT)

# %%
2. Authrization

# %%
3. Rate Limiting and Throttling
 are mechanisms used to control the number of requests a client can make to an API 
within a specific time window. They help prevent:

# %%
4. 4. Input Validation & Sanitization

# %%
5.  5. HTTPS Only

# %%
🔹 6. Use Security Headers

# %%
8. Logging & Monitoring
Track suspicious behavior or attacks.

✅ Tools:

CloudWatch, ELK Stack, Sentry

Monitor for brute force, token reuse, invalid access
