# %%
numbers = [2, 4, 6, 7, 8]
any_even = any(x % 2 == 0 for x in numbers)
all_even = all(x % 2 == 0 for x in numbers)
any_even
# Out:
# True

# %%
merged_dict
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
li = [1,2,3,4]

s = list(map(lambda x : x * x, li))

# %%
s
# Out:
# [1, 4, 9, 16]

# %%
li = [1,2,3,4]
from functools import reduce

s = reduce(lambda y, x : y+ x,li)

# %%
s
# Out:
# 10

# %%
from functools import reduce
l = [1,2,3,4]
s = reduce(lambda x,y : x+ y,l)
s
# Out:
# 10

# %%
from itertools import product,permutations,combinations

# %%
x = [1,2,3]
y = [4,5,6]

s = permutations(x,2)
s

# %%
for i in s:
    print(i)
# Out:
# (1, 2)
# (1, 3)
# (2, 1)
# (2, 3)
# (3, 1)
# (3, 2)

# %%
from collections import Counter
numbers = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
number_counts = Counter(numbers)
for i in number_counts.most_common(2):
    print(i)
# Out:
# (4, 4)
# (3, 3)
