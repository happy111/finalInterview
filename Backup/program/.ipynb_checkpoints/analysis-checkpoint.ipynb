# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"G:\25LAKHS\data\covid_vaccine_statewise.csv")
df.shape
# Out:
# (7845, 24)

# %%
df = df.head(10)

# %%
df.shape
# Out:
# (10, 24)

# %%
df.head(2)
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
#
#    Transgender (Doses Administered)  ...  18-44 Years (Doses Administered)  \
# 0                               NaN  ...                               NaN
# 1                               NaN  ...                               NaN
#
#    45-60 Years (Doses Administered)  60+ Years (Doses Administered)  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
#
#    18-44 Years(Individuals Vaccinated)  45-60 Years(Individuals Vaccinated)  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
#
#    60+ Years(Individuals Vaccinated)  Male(Individuals Vaccinated)  \
# 0                                NaN                       23757.0
# 1                                NaN                       27348.0
#
#    Female(Individuals Vaccinated)  Transgender(Individuals Vaccinated)  \
# 0                         24517.0                                  2.0
# 1                         31252.0                                  4.0
#
#    Total Individuals Vaccinated
# 0                       48276.0
# 1                       58604.0
#
# [2 rows x 24 columns]

# %%
result = []
for index, row in df.iterrows():
    result.append(row)

# %%
df.columns
# Out:
# Index(['Updated On', 'State', 'Total Doses Administered', 'Sessions',
#        ' Sites ', 'First Dose Administered', 'Second Dose Administered',
#        'Male (Doses Administered)', 'Female (Doses Administered)',
#        'Transgender (Doses Administered)', ' Covaxin (Doses Administered)',
#        'CoviShield (Doses Administered)', 'Sputnik V (Doses Administered)',
#        'AEFI', '18-44 Years (Doses Administered)',
#        '45-60 Years (Doses Administered)', '60+ Years (Doses Administered)',
#        '18-44 Years(Individuals Vaccinated)',
#        '45-60 Years(Individuals Vaccinated)',
#        '60+ Years(Individuals Vaccinated)', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Individuals Vaccinated'],
#       dtype='object')

# %%
for k in result:
    print("vvvvvvvvvvvvvvvvvvvvvvvvvvvv",k['First Dose Administered'])
# Out:
# vvvvvvvvvvvvvvvvvvvvvvvvvvvv 48276.0
# vvvvvvvvvvvvvvvvvvvvvvvvvvvv 58604.0
# vvvvvvvvvvvvvvvvvvvvvvvvvvvv 99449.0
# vvvvvvvvvvvvvvvvvvvvvvvvvvvv 195525.0
# vvvvvvvvvvvvvvvvvvvvvvvvvvvv 251280.0
# vvvvvvvvvvvvvvvvvvvvvvvvvvvv 365965.0
# vvvvvvvvvvvvvvvvvvvvvvvvvvvv 549381.0
# vvvvvvvvvvvvvvvvvvvvvvvvvvvv 759008.0
# vvvvvvvvvvvvvvvvvvvvvvvvvvvv 835058.0
# vvvvvvvvvvvvvvvvvvvvvvvvvvvv 1277104.0

# %%
from itertools import product
A = list(map(int,input().strip().split()))
B = list(map(int,input().strip().split()))

s = product(A,B)

for x in s:
    print(x)
print(" ".join(map(str, s)))
# Out:
#  1 2
#  2 3
# (1, 2)
# (1, 3)
# (2, 2)
# (2, 3)

# %%
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)  # Define logger

class PaymentError(Exception):
    pass

def charge_customer():
    raise PaymentError("Payment failed due to insufficient balance")

try:
    charge_customer()
except PaymentError as e:
    logger.error(f"Payment error: {e}")
# Out:
# ERROR:__main__:Payment error: Payment failed due to insufficient balance

# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
