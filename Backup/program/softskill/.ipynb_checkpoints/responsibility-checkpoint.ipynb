# %%
Roles and Responsibilities
**************************

1. Requirement Analysis
2. Query Log preparation(Meeting to business teams)
3. Connect with functional team
4. Raise request for git Repo creation
5. Raise Request for Pipeline Creation
6. Database design
7. Development / coding
8. Unit testing
9. Code Review(Sonarqube)
10. Code Integration (Repo)
11. Code Deployment in Dev Env
12. Integration Testing
13. Bug Fixing
14. SIT support (Whatever Bug identified by sit team. report by jira, fix it )
15. UAT support  (Again test uat team applicatio is a  working as accept or not)
16. Fix issue
17. Prod Support (Final environment) 
18. Preparation Documentation
19. KT for new team memebers

# %%
Introduction
************
1. HI My name is umesh
2. I am having 7 years experience in python technology currently i am working in 
HCl technology
3. Last 7 years i got opportunit work differnt technology like
 python, django, flask, fastapi, pandas, springboot, restapi, microservoce, 
aws cloud, git, docker, etc
5.  I am very good knowledge operation part how appplicatcation deply in aws cloud
6. I am having good experience with unit testing.
7. I am having good experice on the application deployment process using jenkins pipeline.
