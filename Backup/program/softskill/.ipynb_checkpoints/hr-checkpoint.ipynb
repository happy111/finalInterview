# %%
Introduction :-


My name is Umesh Samal, and I have a total of 7 years of experience as a Python Developer.
Over the years, 
I have worked with a wide range of technologies,
including Django, Flask, FastAPI, Microservices architecture, and various unit testing frameworks.
    
I also have hands-on experience with AWS Cloud and several DevOps tools,
particularly Jenkins for CI/CD automation.
I have worked with core AWS services such as EC2, S3, 

and have good exposure to deploying and managing applications in cloud environments.

I enjoy solving technical problems and building scalable systems

Previously, I was working on a banking domain project that consisted of multiple modules.
My role involved developing, testing, and deploying backend services, with a strong focus on code quality, 
performance optimization, and smooth delivery.

# %%
2. Why do you want to join our company?

“I’m impressed by your company’s strong focus on modern technologies, especially your work in the AI space. 
I’m genuinely interested in being part of an organization

# %%
3. What are your strengths?

Sample Answer:

    Strong problem-solving
    Quick learner
    Good team coordination
    Ownership mindset
    Willingness to take responsibility


“One of my weaknesses was that I sometimes spent extra time debugging 
        because I wanted to fully understand the root cause instead of applying a quick fix.
        
Public speaking or presenting

# %%
5. Why should we hire you?

Sample Answer:
“I have hands-on experience in Python, AWS serverless, and backend APIs,
which matches this role. I take ownership of my work and focus on delivering quality results.
    My ability to learn and adapt quickly will help me contribute from day one.”

# %%
6. What motivates you at work?

Sample Answer:
“Solving technical challenges, writing clean code, learning new technologies,
and seeing my work used by real customers motivates me.”

# %%
7. Where do you see yourself in 3–5 years?

Sample Answer:
“I see myself as a senior backend engineer handling architectural decisions,
mentoring junior developers, and contributing to high-impact features.”

# %%
8. Tell me about a challenging situation at work and how you handled it.

Sample Answer:
“In my previous project, we faced performance issues in an API. I analyzed logs,
    optimized the query, added caching, and reduced the response time by 60%.
        This improved user experience and reduced load on the server.”

# %%
9. How do you handle pressure or deadlines?

Sample Answer:
“I break tasks into smaller parts, set priorities,
and keep the team informed. I stay focused, 
avoid multitasking, and deliver quality work even under pressure.”

# %%
What are the expectations from me in the first 3 months?
