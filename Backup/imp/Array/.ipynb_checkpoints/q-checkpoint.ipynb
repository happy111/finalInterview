# %%
Time & Space Complexity
**********************

Total time taken algorithm is called time complexity
Total space take algorithm is called space complexity.


Stack:-
******
Valid parentheses
Next greater element
Reverse stack
Min stack

Queue :-

Queue using stack
Sliding window maximum
First non-repeating character in stream


7️⃣ Searching

Binary search
First & last occurrence
Search in rotated array
Square root using binary search

9️⃣ Recursion

Programs

    Factorial
    Fibonacci
    Reverse string
    Tower of Hanoi

🔟 Backtracking

Programs
Subsets
Permutations
N-Queens
Sudoku solver

11 . Trees
Programs

    Height of tree
    Level order traversal
    Validate BST
    Lowest Common Ancestor
    Diameter of tree

12 . Graphs
Programs
    BFS & DFS
    Detect cycle
    Shortest path
    Topological sort

12 . DP

Programs

    Fibonacci DP
    Knapsack
    Longest Common Subsequence
    Longest Increasing Subsequence
    Coin Change
