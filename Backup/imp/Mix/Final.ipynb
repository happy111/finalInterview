# %%
#  Check anagram
def solve(li):
    temp = {}
    for i in li:
        new_word = ''.join(sorted(i))
        if new_word not in temp:
            temp[new_word] = []
        temp[new_word].append(i)
    return list(temp.values())

li = ['ant','tna','abc','bca','der']
result = solve(li)
print(result)
# Out:
# [['ant', 'tna'], ['abc', 'bca'], ['der']]

# %%
## sort dict via key
def solve(temp):
    new_li = list(temp.keys())
    new_li.sort()
    new_temp = {}
    for i in new_li:
        new_temp[i] = temp[i]
    return new_temp

temp = {1:"dd",2:"rwe",6:"vvcd",4:"sfdasf"}
result = solve(temp)
print(result)
# Out:
# {1: 'dd', 2: 'rwe', 4: 'sfdasf', 6: 'vvcd'}

# %%
## sort dict via value
def solve(temp):
    new_li = list(temp.values())
    new_li.sort()

    new_temp = {}
    for i in new_li:
        for k,v in temp.items():
            if i == v:
                new_temp[k] = v
    return new_temp
temp = {1:"dd",2:"rwe",6:"vvcd",4:"aaa"}
result = solve(temp)
print(result)
# Out:
# {4: 'aaa', 1: 'dd', 2: 'rwe', 6: 'vvcd'}

# %%
## Very important

def group_animals(animals):
    grouped_animals = {}
    for animal in animals:
        if animal not in grouped_animals:
            grouped_animals[animal] = []
            print(grouped_animals)
        grouped_animals[animal].append(animal)

    return list(grouped_animals.values())


animals = ["cat", "dog", "cat"]

# Group the animals
output = group_animals(animals)
print(output)
# Out:
# {'cat': []}
# {'cat': ['cat'], 'dog': []}
# [['cat', 'cat'], ['dog']]

# %%
from collections import defaultdict

def group_anagrams(words):
    anagrams = defaultdict(list)
    for word in words:
        # Sort the word and use it as a key
        sorted_word = tuple(sorted(word))
        anagrams[sorted_word].append(word)
    
    # Convert the dictionary values to a list
    return list(anagrams.values())

words = ["eat", "tea", "tan", "ate", "nat", "bat"]
output = group_anagrams(words)
print(output)
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
li = [1,2,3,4,5]
l2 = [100,200]
output = [1,2,100,200,3,4,5]
i = 2
for k in l2:
    li.insert(i,k)
    i += 1

# %%
li
# Out:
# [1, 2, 100, 200, 3, 4, 5]

# %%
li = [1,2,3,4,5]
ans = lambda x : x*x
s = map(ans,li)
for i in s:
    print(i)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
select max(salary) from emp where salary != (select max(salary) from emp)

# %%
# Reverse a string but space same index
input_str = "abc de ku"
output_str = "uke dc ba"
def solve(input_str):
    space_index = [index for index,char in enumerate(input_str) if char == ' ']
    new_str = [char for char in input_str if char != ' ']
    new_str.reverse()
    print(new_str)
    for index in space_index:
        new_str.insert(index,' ')
    return ' '.join(new_str)

input_str = "abc de ku"
result = solve(input_str)
print(result)
# Out:
# ['u', 'k', 'e', 'd', 'c', 'b', 'a']
# u k e   d c   b a

# %%
## Find Unique element
def solve(li):
    output = []
    for i in li:
        if li.count(i) > 1 and i not in output:
            output.append(i)
    return output


li = [1,2,3,4,1,4,3]
result = solve(li)
print(result)
# Out:
# [1, 3, 4]

# %%
def solve(input):
    new_str = input.replace(' ','1')
    
    new_str1 = input.replace(' ','')

    
    index_space = new_str.index('1')
    output = ""

    for i in range(len(new_str1)-1,-1,-1):
        if i == 1:
            output = output + " "+ new_str1[i]
        else:
            output = output + new_str1[i]

    return output



input = "abc de"
output =  "edc ba"
result = solve(input)
print(result)
# Out:
# edc ba

# %%
import time
def sum1(abc):
    start_time = time.time()
    def demo(a,b):
        c = abc(a,b)
        take_time = time.time()-start_time
        return take_time
    return demo

@sum1
def sum(a,b):
    return a+b
sum(4,6)
# Out:
# 0.0

# %%
def solve(li):
    for i in range(len(li)):
        for j in range(i,len(li)):
            if li[i] > li[j]:
                li[i],li[j] = li[j],li[i]
    return li

li = [23,45,12,11,3]
result = solve(li)
print(result)

# %%
def solve(str):
    if not str:  # Edge case: empty string
        return 0
    ch = str[0]
    count = 1
    max_count = 1
    
    for i in range(1, len(str)):
        if str[i] == ch:
            count += 1
        else:
            if count > max_count:
                max_count = count
            ch = str[i]
            count = 1
    
    # Final check at the end of the string
    if count > max_count:
        max_count = count
    
    return max_count

str = "AAABBCCCDDDDAAAAAAAAAAAA"
result = solve(str)
print(result)
# Out:
# 12

# %%
def solve(sentence):
    str = sentence.split(" ")
    output = []
    for i in str:
        if i == i[::-1]:
            output.append(i)
    return output

sentence = "His dad knows malayalam and he is a reviver"
result = solve(sentence)
print(result)
# Out:
# ['dad', 'malayalam', 'a', 'reviver']

# %%
A = [“This”, “is”, “a”, “wonderful”, “day”]
Return list sorted based on length

# %%
def solve(A):
    temp = []
    for i in A:
        temp.append(len(i))
    temp.sort()
    
    output = []
    for i in temp:
        for k in A:
            if i == len(k):
                output.append(k)
    return output

A = ["This", "is", "a", "wonderful", "day"]
result = solve(A)
print(result)
# Out:
# ['a', 'is', 'day', 'This', 'wonderful']

# %%
class School:
    def __init__(self,name):
        self.name = name
        
class Student(School):
    def __init__(self,name,st_name):
        self.st_name = st_name
        super().__init__(name)
    
    def display(self):
        print("School Name is",self.name)
        
obj = Student("Ram","DPS")
obj.display()

# %%
def solve(arr):
    maxsum = 0
    firstindex = ""
    lastindex = ""
    for i in range(len(arr)):
        for j in range(i,len(arr)):
            sum = 0
            for s in range(i,j+1):
                sum += arr[s]
            if maxsum < sum:
                maxsum = sum
                firstindex = i
                lastindex = j
    return arr[firstindex:lastindex+1],maxsum

arr = [-6, 9, -3, 4, -7, 2, 1, -1, 7, -2, -4, 4]
#arr = [10,20,30]
result,sum = solve(arr)

print(result,sum)
# Out:
# [9, -3, 4, -7, 2, 1, -1, 7] 12

# %%
def solve(arr):
    maxsum = 0
    firstindex = ""
    lastindex = ""
    for i in range(len(arr)):
        for j in range(i,len(arr)):
            sum = 0
            for s in range(i,j+1):
                sum += arr[s]
            if maxsum < sum:
                maxsum = sum
                firstindex = i
                lastindex = j
    return arr[firstindex:lastindex]

arr = [-6, 9, -3, 4, -7, 2, 1, -1, 7, -2, -4, 4]

result = solve(arr)

print(result)

# %%
def Find_max_sum(arr):
    ps = [arr[0]]
    for i in range(1,len(arr)):
        ps.append(ps[i-1]+arr[i])
    max  = 0
    for s in range(len(arr)):
        for e in range(s,len(arr)):
            sum = 0
            if s != 0:
                sum += ps[e] - ps[s-1]
            else:
                sum += ps[e]
            if max < sum:
                max = sum   
    return max

arr = [10,20,30,50]
arr = [-6, 9, -3, 4, -7, 2, 1, -1, 7, -2, -4, 4]

result = Find_max_sum(arr)
print(result)

# %%
def solve(arr):
    pf = [arr[0]]
    for i in range(1,len(arr)):
        pf.append(pf[i-1]+arr[i])
    max = 0
    for i in range(len(arr)):
        for j in range(i,len(arr)):
            sum = 0
            if i == 0:
                sum += pf[j]
            else:
                sum += pf[j] - pf[i-1]
            if max < sum:
                max = sum
    return max,1


arr = [-6, 9, -3, 4, -7, 2, 1, -1, 7, -2, -4, 4]

result,sum = solve(arr)
print(result,sum)

# %%
# Out:
# 25

# %%
import pandas as pd
data = {
    'Student': ['Alice', 'Bob', 'Charlie', 'David'],
    'Math':   [85, 90, 75, 80],
    'Science': [88, 85, 90, 82],
    'English': [82, 88, 85, 90]
}
df = pd.DataFrame(data)
print(df)
def calculate_percentage(data):
    print(data['Math'])
    
df['percentage'] = df.apply(lambda x:calculate_percentage(x),axis=1)
    
df
# Out:
#    Student  Math  Science  English
# 0    Alice    85       88       82
# 1      Bob    90       85       88
# 2  Charlie    75       90       85
# 3    David    80       82       90
# 85
# 90
# 75
# 80
#    Student  Math  Science  English percentage
# 0    Alice    85       88       82       None
# 1      Bob    90       85       88       None
# 2  Charlie    75       90       85       None
# 3    David    80       82       90       None

# %%
Problem Statement: Write Python code to find the longest common prefix in a given list of strings.

Sample Input:
 
['car', 'carbon', 'carbonmonoxide']
 
Sample Output:
 
'car'
 
Sample Input:
 
['car', 'carbon', 'vehicle']
 
Sample Output:

# %%
def solve(res):
    if not res:
        return ""
    # Find the smallest word (optimization)
    smallest_word = min(res, key=len)
    output = ""
    for i in range(len(smallest_word)):
        char = smallest_word[i]
        for word in res:
            if word[i] != char:
                return output
        output += char
    return output


# Test cases
res1 = ['car', 'carbon', 'vehicle']
res2 = ['carbon', 'carbonmonoxide']
res12 = ["abcd", "abcc", "abcde"]

print(solve(res1))   # Output: ""
print(solve(res2))   # Output: "carbon"
print(solve(res12))  # Output: "abc"
# Out:
# carbon
# abc

# %%
res2 = ['carbon', 'carbonmonoxide']

prefix = ""
for a, b in zip(res2[0], res2[1]):
    if a == b:
        prefix += a
    else:
        break

print(prefix)
# Out:
# carbon

# %%
Problem statement: Find smallest and largest palindrom word in given string
input: "you abbba abcded own wow kayak"
output: wow,abbba

# %%
def solve(input):
    input = input.split(" ")
    smallest = ""
    largest = ""
    smallest_len = float('inf')
    largest_len = 0
    for i in input:
        if i == i[::-1]:
            if smallest_len > len(i):
                smallest_len = len(i)
                smallest = i        if i == i[::-1]:
            if largest_len < len(i):
                largest_len = len(i)
                largest = i
    print("Smallest palindrom is ", smallest)
    print("Largest palindrom is", largest)

input = "you abbba abcded own wow kayak"
result = solve(input)
# Out:
# Smallest palindrom is  wow
# Largest palindrom is abbba

# %%
def solve(coins,target):
    pf = [coins[0]]
    for i in range(1,len(coins)):
        pf.append(pf[i-1] + coins[i])

    min_len = float('inf')
    ans = []
    for s in range(len(coins)):
        for e in range(s,len(coins)):
            sum = 0
            if s == 0:
                sum += pf[e]
            else:
                sum += pf[e] - pf[s-1]
            if sum == target:
                val = coins[s:e+1]
                if min_len > len(val):
                    min_len = len(val)
                    ans = val
    return ans


coins = [1,2,3,5,6,7]
target = 11
result = solve(coins,target)
print(result)
# Out:
# [1, 3, 6, 11, 17, 24]
# [5, 6]

# %%
def solve(li,k):
    ans = []
    for i in range(len(li)-2):
        temp = {}
        cs = k - li[i]
        for j in range(i+1,len(li)):
            if cs-li[j] in temp:
                ans.append([li[i],li[j],cs-li[j]])
            temp[li[j]] = j
    return ans

li = [3, 4, 5, 2, 1, 2]
k = 9
result = solve(li, k)
# Print the results in the desired format
print(result)
# Out:
# [[3, 2, 4], [3, 1, 5], [3, 2, 4], [5, 2, 2]]
