# %%
1. What is Flask?
  . Flask is a lightweight, 
    micro web framework in Python used to build web applications and REST APIs.
  . Flask provides only the core features (routing, request/response, templating).
Everything else (ORM, auth, database) is added using extensions.

# %%
3. What is app.route()?

@app.route() is a decorator that maps a URL to a Python function.

@app.route('/hello')
def hello():
    return "Hello World"

# %%
5. How do you enable debugging in Flask?

app.run(debug=True)

# %%
6. What is request in Flask?

request is an object containing client request data:

headers
URL params
body
cookies
files

# %%
app.config['SQLALCHEMY_DATABASE_URI'] = 'mysql+pymysql://root:pwd@localhost/db'

# %%
8. How to return JSON in Flask?

from flask import jsonify
return jsonify({"message": "success"})

# %%
11. What is a Blueprint?

Blueprints let you divide your application into modules (modular structure).

# %%
Request Context

Holds data related to the current request:
    request
    session

Application Context
    Holds data related to the Flask app:

    current_app
    g (global variable)

# %%
18. What is before_request and after_request?

Hooks executed before and after each request.

@app.before_request
def before():
    print("Before request")

# %%
21. How do you implement JWT authentication?

access_token = create_access_token(identity=user.id)

# %%
25. How do you structure a large Flask application?

Use:

Blueprints
config files
models folder
services folder
tests folder

# %%
3. What are the key features of Flask?

Lightweight
Built-in development server
Jinja2 template engine
REST API friendly

# %%
# !pip install flask

# %%
from flask import Flask
app = Flask(__name__)

@app.route('/')
def home():
    return "Hello Flask"

# %%
from flask import jsonify
return jsonify({"status": "ok"})

# %%
13. What are Flask Blueprints?

Used to create modular, structured applications.

# %%
14. What is Flask-SQLAlchemy?

ORM layer to interact with relational databases.

# %%
myapp/
│
├── app.py
├── config.py
├── requirements.txt
│
├── db/
│   ├── __init__.py
│   └── database.py
│
├── models/
│   ├── __init__.py
│   └── user.py
│
├── services/
│   ├── __init__.py
│   └── user_service.py
│
└── routes/
    ├── __init__.py
    └── user_routes.py

# %%
✅ config.py
class Config:
    SQLALCHEMY_DATABASE_URI = "mysql+pymysql://root:password@localhost:3306/testdb"
    SQLALCHEMY_TRACK_MODIFICATIONS = False
    SECRET_KEY = "your-secret-key"

# %%
✅ Now run these commands
1️⃣ Initialize migrations
flask --app app.py db init

2️⃣ Create migration file
flask --app app.py db migrate -m "initial"

3️⃣ Apply migration
flask --app app.py db upgrade
