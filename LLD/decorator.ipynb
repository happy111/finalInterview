# %%
#  Decorator Design Pattern

Decorator Pattern lets you add extra features/behaviours to an object
at runtime without modifying the original class.

1️⃣ Swiggy/Zomato Food Order – Add-ons

You order a pizza → then add
✔ Cheese burst
✔ Extra toppings
✔ Extra sauce

# %%
Boss
run() -> "Running"

Child
run() ->  "Running with child"


Boss b = new Child()
b.run()  -> Running with child

Boss b = new Boss()
b.run() ->

# %%
def log(func):
    def wrapper(*args, **kwargs):
        print(f"Calling: {func.__name__}")
        return func(*args, **kwargs)
    return wrapper

# %%
def authenticate(func):
    def wrapper(*args, **kwargs):
        print("Checking authentication...")
        return func(*args, **kwargs)
    return wrapper

# %%
@log
@authenticate
def get_user_data():
    print("User data fetched")

get_user_data()
# Out:
# Calling: wrapper
# Checking authentication...
# User data fetched
