# %%
# SQL Query to Convert 0 → 1 and 1 → 0

# %%
UPDATE employee_status
SET is_active = CASE 
                   WHEN is_active = 1 THEN 0
                   WHEN is_active = 0 THEN 1
                END;
