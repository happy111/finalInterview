# %%
SELECT name FROM customer where referee_id != 102;

# %%
select distinct customer_id from customers where year=2021 and revenue>0

# %%
select  id from cinema where id % 2 != 0 and description != 'boring' order by rating desc;

# %%
UPDATE Salary
SET sex = CASE 
             WHEN sex = 'm' THEN 'f'
             WHEN sex = 'f' THEN 'm'
          END;

SELECT * FROM Salary;

# %%
UPDATE Salary
SET sex = CASE 
             WHEN sex = 'm' THEN 'f'
             WHEN sex = 'f' THEN 'm'
          END;

SELECT * FROM Salary;

# %%
SELECT
    CASE
        WHEN x + y > z AND
             x + z > y AND
             y + z > x
        THEN 'Yes'
        ELSE 'No'
    END as triangle
    from Triangle

# %%
SELECT productCode, 
SUBSTR(productDescription, 1, 20) AS shortDescription
FROM products
order by productCode;

# %%
select emp_id, name ,salary,
ROUND(((salary * 20 / 100))+salary) AS New_salary from employees
ORDER BY emp_id;

# %%
select orderNumber,productCode,round((quantityOrdered * priceEach),2) AS sub_total
FROM orderdetails order by orderNumber,sub_total desc;
